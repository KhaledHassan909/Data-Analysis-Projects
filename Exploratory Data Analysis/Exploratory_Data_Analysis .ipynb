# %% [markdown]
# # Ford Go-bike Exploratory Analysis
# ## 1. Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
# Loading DataSet into Pandas Dataframe
df = pd.read_csv('fordgobike_tripdata.csv')
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 1               37.791464              -122.391034            81.0
# 2               37.769305              -122.426826             3.0
# 3               37.774836              -122.446546            70.0
# 4               37.804562              -122.271738           222.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 1                            Berry St at 4th St             37.775880
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 3                        Central Ave at Fell St             37.773311
# 4                         10th Ave at E 15th St             37.792714
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 1            -122.393170     2535    Customer                NaN
# 2            -122.404904     5905    Customer             1972.0
# 3            -122.444293     6638  Subscriber             1989.0
# 4            -122.248780     4898  Subscriber             1974.0
#
#   member_gender bike_share_for_all_trip
# 0          Male                      No
# 1           NaN                      No
# 2          Male                      No
# 3         Other                      No
# 4          Male                     Yes

# %%
df['bike_share_for_all_trip'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['member_gender'].unique()
# Out:
# array(['Male', nan, 'Other', 'Female'], dtype=object)

# %%
df[df['member_gender'] == 'Other']
# Out:
#         duration_sec                start_time                  end_time  \
# 3              36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 8               1570  2019-02-28 23:41:48.7900  2019-03-01 00:07:59.7150
# 131             1187  2019-02-28 22:39:58.5600  2019-02-28 22:59:46.2060
# 135              544  2019-02-28 22:48:12.7300  2019-02-28 22:57:17.0800
# 190              515  2019-02-28 22:28:11.3470  2019-02-28 22:36:46.3890
# 231              244  2019-02-28 22:21:46.8260  2019-02-28 22:25:51.2500
# 261              748  2019-02-28 22:03:01.7060  2019-02-28 22:15:30.3670
# 710              485  2019-02-28 20:36:18.5170  2019-02-28 20:44:23.6630
# 798              975  2019-02-28 20:13:20.5050  2019-02-28 20:29:35.6690
# 827              352  2019-02-28 20:19:41.5110  2019-02-28 20:25:34.1210
# 887              542  2019-02-28 20:09:07.2530  2019-02-28 20:18:09.8540
# 892              655  2019-02-28 20:05:55.8520  2019-02-28 20:16:51.3700
# 919             1264  2019-02-28 19:52:28.8720  2019-02-28 20:13:33.5370
# 922              753  2019-02-28 20:00:40.3760  2019-02-28 20:13:13.8190
# 928              291  2019-02-28 20:07:34.9590  2019-02-28 20:12:26.3480
# 1075             415  2019-02-28 19:47:39.8680  2019-02-28 19:54:35.0390
# 1087             537  2019-02-28 19:44:08.8290  2019-02-28 19:53:06.1610
# 1106             851  2019-02-28 19:36:45.2310  2019-02-28 19:50:57.0650
# 1123             366  2019-02-28 19:42:18.5310  2019-02-28 19:48:25.2980
# 1176            1484  2019-02-28 19:17:32.4590  2019-02-28 19:42:17.3290
# 1211             617  2019-02-28 19:27:34.8010  2019-02-28 19:37:52.0150
# 1394             752  2019-02-28 19:09:18.0740  2019-02-28 19:21:50.7520
# 1419             517  2019-02-28 19:09:49.1890  2019-02-28 19:18:26.3200
# 1432             398  2019-02-28 19:09:44.2940  2019-02-28 19:16:23.2800
# 1560             614  2019-02-28 18:55:29.1720  2019-02-28 19:05:43.9160
# 1633            1138  2019-02-28 18:41:23.8310  2019-02-28 19:00:22.3990
# 1654             632  2019-02-28 18:48:30.4750  2019-02-28 18:59:03.1160
# 1672            1069  2019-02-28 18:39:58.7280  2019-02-28 18:57:48.0510
# 1756             857  2019-02-28 18:37:55.3430  2019-02-28 18:52:12.5530
# 1777             356  2019-02-28 18:44:36.8080  2019-02-28 18:50:33.1790
# ...              ...                       ...                       ...
# 181369           306  2019-02-01 09:17:25.0870  2019-02-01 09:22:32.0820
# 181455           286  2019-02-01 09:13:53.3180  2019-02-01 09:18:39.7440
# 181490           621  2019-02-01 09:06:32.2070  2019-02-01 09:16:53.5050
# 181573           597  2019-02-01 09:01:42.4820  2019-02-01 09:11:39.7980
# 181606           270  2019-02-01 09:05:37.5030  2019-02-01 09:10:07.7910
# 181652           598  2019-02-01 08:57:44.4730  2019-02-01 09:07:43.0910
# 181780          1385  2019-02-01 08:38:22.1440  2019-02-01 09:01:27.9350
# 181909            73  2019-02-01 08:52:29.6030  2019-02-01 08:53:43.4490
# 181940           585  2019-02-01 08:42:09.2220  2019-02-01 08:51:54.6490
# 181963           262  2019-02-01 08:46:02.9160  2019-02-01 08:50:24.9490
# 181981           341  2019-02-01 08:44:01.6170  2019-02-01 08:49:42.6430
# 181986          2055  2019-02-01 08:15:14.4760  2019-02-01 08:49:30.1860
# 182133          6086  2019-02-01 07:00:02.0420  2019-02-01 08:41:28.2510
# 182153          1280  2019-02-01 08:19:13.5950  2019-02-01 08:40:34.1650
# 182492           499  2019-02-01 08:12:24.7480  2019-02-01 08:20:44.3950
# 182560          1003  2019-02-01 07:59:39.1370  2019-02-01 08:16:22.9930
# 182661           410  2019-02-01 08:00:25.4420  2019-02-01 08:07:15.6860
# 182697           770  2019-02-01 07:50:46.6260  2019-02-01 08:03:37.4880
# 182738           665  2019-02-01 07:49:01.7650  2019-02-01 08:00:07.1230
# 182807           577  2019-02-01 07:45:09.5210  2019-02-01 07:54:47.3830
# 182871           397  2019-02-01 07:40:49.9320  2019-02-01 07:47:27.2310
# 183060          1616  2019-02-01 06:54:49.0400  2019-02-01 07:21:45.6570
# 183075           332  2019-02-01 07:13:17.7140  2019-02-01 07:18:50.2980
# 183228           192  2019-02-01 06:30:18.3140  2019-02-01 06:33:30.4480
# 183309          1099  2019-02-01 03:23:23.2050  2019-02-01 03:41:42.5910
# 183346           312  2019-02-01 02:06:04.5660  2019-02-01 02:11:17.1220
# 183349           527  2019-02-01 01:48:54.7550  2019-02-01 01:57:42.5400
# 183378           659  2019-02-01 00:53:36.1430  2019-02-01 01:04:35.3710
# 183381           426  2019-02-01 00:48:54.1590  2019-02-01 00:56:00.4740
# 183389           184  2019-02-01 00:43:56.5560  2019-02-01 00:47:01.0090
#
#         start_station_id                                 start_station_name  \
# 3                  375.0                            Grove St at Masonic Ave
# 8                   10.0                         Washington St at Kearny St
# 131                262.0                          West St at University Ave
# 135                356.0                        Valencia St at Clinton Park
# 190                 58.0                               Market St at 10th St
# 231                 75.0                           Market St at Franklin St
# 261                 74.0                              Laguna St at Hayes St
# 710                181.0                            Grand Ave at Webster St
# 798                156.0                          Stanford Ave at Hollis St
# 827                163.0                          Lake Merritt BART Station
# 887                258.0                        University Ave at Oxford St
# 892                 41.0                         Golden Gate Ave at Polk St
# 919                176.0                             MacArthur BART Station
# 922                 76.0                         McCoppin St at Valencia St
# 928                223.0                     16th St Mission BART Station 2
# 1075               323.0                                 Broadway at Kearny
# 1087               258.0                        University Ave at Oxford St
# 1106                67.0  San Francisco Caltrain Station 2  (Townsend St...
# 1123               160.0                          West Oakland BART Station
# 1176                21.0   Montgomery St BART Station (Market St at 2nd St)
# 1211               349.0                               Howard St at Mary St
# 1394                 6.0                      The Embarcadero at Sansome St
# 1419                 4.0                        Cyril Magnin St at Ellis St
# 1432                 3.0       Powell St BART Station (Market St at 4th St)
# 1560               150.0                              Adeline St at 40th St
# 1633               187.0                                 Jack London Square
# 1654                47.0                              4th St at Harrison St
# 1672               176.0                             MacArthur BART Station
# 1756               197.0                        El Embarcadero at Grand Ave
# 1777               104.0                                  4th St at 16th St
# ...                  ...                                                ...
# 181369             106.0                              Sanchez St at 17th St
# 181455              80.0                              Townsend St at 5th St
# 181490             350.0                               8th St at Brannan St
# 181573             200.0                               2nd Ave at E 18th St
# 181606             267.0                            Derby St at College Ave
# 181652             171.0                             Rockridge BART Station
# 181780             270.0                              Ninth St at Heinz Ave
# 181909             253.0                            Haste St at College Ave
# 181940             110.0   17th & Folsom Street Park (17th St at Folsom St)
# 181963              18.0                      Telegraph Ave at Alcatraz Ave
# 181981             274.0                            Oregon St at Adeline St
# 181986             193.0                       Grand Ave at Santa Clara Ave
# 182133             380.0                             Masonic Ave at Turk St
# 182153             166.0                        College Ave at Alcatraz Ave
# 182492             159.0                               24th St at Market St
# 182560             246.0                              Berkeley Civic Center
# 182661             180.0                           Telegraph Ave at 23rd St
# 182697              96.0                              Dolores St at 15th St
# 182738             204.0                           55th St at Telegraph Ave
# 182807             214.0                         Market St at Brockhurst St
# 182871              61.0                                Howard St at 8th St
# 183060              85.0                            Church St at Duboce Ave
# 183075             250.0                        North Berkeley BART Station
# 183228             321.0                                   5th St at Folsom
# 183309             166.0                        College Ave at Alcatraz Ave
# 183346             175.0                           49th St at Telegraph Ave
# 183349             213.0                              32nd St at Adeline St
# 183378              47.0                              4th St at Harrison St
# 183381             230.0                            14th St at Mandela Pkwy
# 183389              66.0                              3rd St at Townsend St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 3                    37.774836              -122.446546            70.0
# 8                    37.795393              -122.404770           127.0
# 131                  37.869967              -122.286533           240.0
# 135                  37.769188              -122.422285            34.0
# 190                  37.776619              -122.417385           321.0
# 231                  37.773793              -122.421239            58.0
# 261                  37.776435              -122.426244            30.0
# 710                  37.811377              -122.265192           193.0
# 798                  37.838443              -122.288665           232.0
# 827                  37.797320              -122.265320           200.0
# 887                  37.872355              -122.266447           258.0
# 892                  37.781270              -122.418740            39.0
# 919                  37.828410              -122.266315           156.0
# 922                  37.771662              -122.422423           323.0
# 928                  37.764765              -122.420091            86.0
# 1075                 37.798014              -122.405950            21.0
# 1087                 37.872355              -122.266447           258.0
# 1106                 37.776639              -122.395526            74.0
# 1123                 37.805318              -122.294837           235.0
# 1176                 37.789625              -122.400811           134.0
# 1211                 37.781010              -122.405666           109.0
# 1394                 37.804770              -122.403234            81.0
# 1419                 37.785881              -122.408915           323.0
# 1432                 37.786375              -122.404904            67.0
# 1560                 37.831277              -122.278267           149.0
# 1633                 37.796248              -122.279352           315.0
# 1654                 37.780955              -122.399749           126.0
# 1672                 37.828410              -122.266315           207.0
# 1756                 37.808848              -122.249680           187.0
# 1777                 37.767045              -122.390833           115.0
# ...                        ...                      ...             ...
# 181369               37.763242              -122.430675           223.0
# 181455               37.775235              -122.397437           114.0
# 181490               37.771431              -122.405787            21.0
# 181573               37.800214              -122.253810             7.0
# 181606               37.861804              -122.253569           243.0
# 181652               37.844279              -122.251900           243.0
# 181780               37.853489              -122.289415             7.0
# 181909               37.866418              -122.253799           243.0
# 181940               37.763708              -122.415204           104.0
# 181963               37.850222              -122.260172           248.0
# 181981               37.857567              -122.267558           246.0
# 181986               37.812744              -122.247215           245.0
# 182133               37.779047              -122.447291           377.0
# 182153               37.851376              -122.252523             7.0
# 182492               37.816060              -122.278244           181.0
# 182560               37.869060              -122.270556           150.0
# 182661               37.812678              -122.268773           212.0
# 182697               37.766210              -122.426614            21.0
# 182738               37.840186              -122.261823           239.0
# 182807               37.823321              -122.275732           176.0
# 182871               37.776513              -122.411306            79.0
# 183060               37.770083              -122.429156            15.0
# 183075               37.873558              -122.283093           254.0
# 183228               37.780146              -122.403071             5.0
# 183309               37.851376              -122.252523           213.0
# 183346               37.835946              -122.262366           166.0
# 183349               37.823847              -122.281193           158.0
# 183378               37.780955              -122.399749            67.0
# 183381               37.810743              -122.291415           213.0
# 183389               37.778742              -122.392741            47.0
#
#                                          end_station_name  \
# 3                                  Central Ave at Fell St
# 8                                  Valencia St at 21st St
# 131                             Haste St at Telegraph Ave
# 135                        Father Alfred E Boeddeker Park
# 190                                      5th St at Folsom
# 231                                  Market St at 10th St
# 261        San Francisco Caltrain (Townsend St at 4th St)
# 710                          Grand Ave at Santa Clara Ave
# 798                                 MLK Jr Way at 14th St
# 827                                  2nd Ave at E 18th St
# 887                           University Ave at Oxford St
# 892                           Scott St at Golden Gate Ave
# 919                             Stanford Ave at Hollis St
# 922                                    Broadway at Kearny
# 928                               Market St at Dolores St
# 1075     Montgomery St BART Station (Market St at 2nd St)
# 1087                          University Ave at Oxford St
# 1106                                Laguna St at Hayes St
# 1123                                  Union St at 10th St
# 1176                               Valencia St at 24th St
# 1211                               17th St at Valencia St
# 1394                                   Berry St at 4th St
# 1419                                   Broadway at Kearny
# 1432    San Francisco Caltrain Station 2  (Townsend St...
# 1560                                 Emeryville Town Hall
# 1633                                 Market St at 45th St
# 1654                                          Esprit Park
# 1672                             Broadway at Coronado Ave
# 1756                                   Jack London Square
# 1777                                   Jackson Playground
# ...                                                   ...
# 181369                     16th St Mission BART Station 2
# 181455                         Rhode Island St at 17th St
# 181490   Montgomery St BART Station (Market St at 2nd St)
# 181573                                Frank H Ogawa Plaza
# 181606                        Bancroft Way at College Ave
# 181652                        Bancroft Way at College Ave
# 181780                                Frank H Ogawa Plaza
# 181909                        Bancroft Way at College Ave
# 181940                                  4th St at 16th St
# 181963                         Telegraph Ave at Ashby Ave
# 181981                              Berkeley Civic Center
# 181986                             Downtown Berkeley BART
# 182133                              Fell St at Stanyan St
# 182153                                Frank H Ogawa Plaza
# 182492                            Grand Ave at Webster St
# 182560                              Adeline St at 40th St
# 182661                                      Mosswood Park
# 182697   Montgomery St BART Station (Market St at 2nd St)
# 182738                      Bancroft Way at Telegraph Ave
# 182807                             MacArthur BART Station
# 182871                               7th St at Brannan St
# 183060  San Francisco Ferry Building (Harry Bridges Pl...
# 183075                            Vine St at Shattuck Ave
# 183228       Powell St BART Station (Market St at 5th St)
# 183309                              32nd St at Adeline St
# 183346                        College Ave at Alcatraz Ave
# 183349                      Shattuck Ave at Telegraph Ave
# 183378  San Francisco Caltrain Station 2  (Townsend St...
# 183381                              32nd St at Adeline St
# 183389                              4th St at Harrison St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 3                  37.773311            -122.444293     6638  Subscriber
# 8                  37.756708            -122.421025     6548  Subscriber
# 131                37.866043            -122.258804     5649  Subscriber
# 135                37.783988            -122.412408     6065  Subscriber
# 190                37.780146            -122.403071     5234  Subscriber
# 231                37.776619            -122.417385      481  Subscriber
# 261                37.776598            -122.395282     6520  Subscriber
# 710                37.812744            -122.247215     4579  Subscriber
# 798                37.806163            -122.276040     6060  Subscriber
# 827                37.800214            -122.253810     3505  Subscriber
# 887                37.872355            -122.266447      777  Subscriber
# 892                37.778999            -122.436861     5150  Subscriber
# 919                37.838443            -122.288665     2598  Subscriber
# 922                37.798014            -122.405950     6477  Subscriber
# 928                37.769305            -122.426826     6463  Subscriber
# 1075               37.789625            -122.400811     6381  Subscriber
# 1087               37.872355            -122.266447      777  Subscriber
# 1106               37.776435            -122.426244     4567  Subscriber
# 1123               37.807239            -122.289370     6392  Subscriber
# 1176               37.752428            -122.420628     2330  Subscriber
# 1211               37.763316            -122.421904     5037  Subscriber
# 1394               37.775880            -122.393170     4619  Subscriber
# 1419               37.798014            -122.405950     6381  Subscriber
# 1432               37.776639            -122.395526     2321  Subscriber
# 1560               37.831275            -122.285633     5514  Subscriber
# 1633               37.834174            -122.272968     4523  Subscriber
# 1654               37.761634            -122.390648     1475  Subscriber
# 1672               37.835788            -122.251621     6000  Subscriber
# 1756               37.796248            -122.279352     6408  Subscriber
# 1777               37.765026            -122.398773     1564  Subscriber
# ...                      ...                    ...      ...         ...
# 181369             37.764765            -122.420091     3359  Subscriber
# 181455             37.764478            -122.402570     5540  Subscriber
# 181490             37.789625            -122.400811     5045  Subscriber
# 181573             37.804562            -122.271738     1889  Subscriber
# 181606             37.869360            -122.254337      668  Subscriber
# 181652             37.869360            -122.254337     4588  Subscriber
# 181780             37.804562            -122.271738     5493    Customer
# 181909             37.869360            -122.254337     3232  Subscriber
# 181940             37.767045            -122.390833     4966  Subscriber
# 181963             37.855956            -122.259795     3471  Subscriber
# 181981             37.869060            -122.270556     4890    Customer
# 181986             37.870139            -122.268422      325  Subscriber
# 182133             37.771917            -122.453704     4956  Subscriber
# 182153             37.804562            -122.271738     4485  Subscriber
# 182492             37.811377            -122.265192     4543  Subscriber
# 182560             37.831277            -122.278267     3347  Subscriber
# 182661             37.824893            -122.260437     5499    Customer
# 182697             37.789625            -122.400811     5288  Subscriber
# 182738             37.868813            -122.258764     4581  Subscriber
# 182807             37.828410            -122.266315     2534  Subscriber
# 182871             37.773492            -122.403673     1841  Subscriber
# 183060             37.795392            -122.394203     5404  Subscriber
# 183075             37.880222            -122.269592     5111  Subscriber
# 183228             37.783899            -122.408445     5007  Subscriber
# 183309             37.823847            -122.281193     5450  Subscriber
# 183346             37.851376            -122.252523     5450  Subscriber
# 183349             37.833279            -122.263490     1172  Subscriber
# 183378             37.776639            -122.395526     4960  Subscriber
# 183381             37.823847            -122.281193     3535  Subscriber
# 183389             37.780955            -122.399749     4960  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 3                  1989.0         Other                      No
# 8                  1988.0         Other                      No
# 131                1993.0         Other                      No
# 135                1991.0         Other                      No
# 190                1981.0         Other                      No
# 231                1981.0         Other                      No
# 261                1985.0         Other                      No
# 710                1983.0         Other                      No
# 798                1982.0         Other                      No
# 827                1984.0         Other                      No
# 887                1987.0         Other                      No
# 892                1968.0         Other                      No
# 919                1963.0         Other                      No
# 922                1995.0         Other                     Yes
# 928                1976.0         Other                      No
# 1075               1976.0         Other                      No
# 1087               1987.0         Other                      No
# 1106               1985.0         Other                      No
# 1123               1990.0         Other                     Yes
# 1176               1986.0         Other                      No
# 1211               1996.0         Other                      No
# 1394               1983.0         Other                      No
# 1419               1976.0         Other                      No
# 1432               1985.0         Other                      No
# 1560               1987.0         Other                      No
# 1633               1964.0         Other                      No
# 1654               1980.0         Other                      No
# 1672               1985.0         Other                      No
# 1756               1993.0         Other                      No
# 1777               1984.0         Other                     Yes
# ...                   ...           ...                     ...
# 181369             1984.0         Other                      No
# 181455             1975.0         Other                      No
# 181490             1988.0         Other                      No
# 181573             1984.0         Other                      No
# 181606             1997.0         Other                     Yes
# 181652             1962.0         Other                      No
# 181780             1983.0         Other                      No
# 181909             1997.0         Other                     Yes
# 181940             1980.0         Other                      No
# 181963             1985.0         Other                      No
# 181981             1994.0         Other                      No
# 181986             1993.0         Other                      No
# 182133             1971.0         Other                      No
# 182153             1965.0         Other                      No
# 182492             1990.0         Other                      No
# 182560             1979.0         Other                      No
# 182661             1984.0         Other                      No
# 182697             1989.0         Other                      No
# 182738             1966.0         Other                      No
# 182807             1992.0         Other                      No
# 182871             1967.0         Other                      No
# 183060             1964.0         Other                     Yes
# 183075             1987.0         Other                      No
# 183228             1981.0         Other                      No
# 183309             1997.0         Other                     Yes
# 183346             1997.0         Other                     Yes
# 183349             1997.0         Other                     Yes
# 183378             1985.0         Other                      No
# 183381             1997.0         Other                     Yes
# 183389             1985.0         Other                      No
#
# [3652 rows x 16 columns]

# %%
# High level overview of DataSet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
# duration_sec               183412 non-null int64
# start_time                 183412 non-null object
# end_time                   183412 non-null object
# start_station_id           183215 non-null float64
# start_station_name         183215 non-null object
# start_station_latitude     183412 non-null float64
# start_station_longitude    183412 non-null float64
# end_station_id             183215 non-null float64
# end_station_name           183215 non-null object
# end_station_latitude       183412 non-null float64
# end_station_longitude      183412 non-null float64
# bike_id                    183412 non-null int64
# user_type                  183412 non-null object
# member_birth_year          175147 non-null float64
# member_gender              175147 non-null object
# bike_share_for_all_trip    183412 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
# Shape of DataSet
df.shape
# Out:
# (183412, 16)

# %%
# Descriptive Statistics of numeric values in DataSet
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183412.000000     183215.000000           183412.000000
# mean      726.078435        138.590427               37.771223
# std      1794.389780        111.778864                0.099581
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183412.000000   183215.000000         183412.000000
# mean               -122.352664      136.249123             37.771427
# std                   0.117097      111.515131              0.099490
# min                -122.453704        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183412.000000  183412.000000      175147.000000
# mean             -122.352250    4472.906375        1984.806437
# std                 0.116673    1664.383394          10.116689
# min              -122.453704      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %% [markdown]
# ### What is the structure of dataset?

# %% [markdown]
# Number of bikes to be considerd are 183412 bikes, each bike has 16 different features to be considerd<br> (duration_sec , start_time , end_time , start_station_id , start_station_name , start_station_latitude , start_station_longitude , start_station_id , end_station_name , end_station_latitude , end_station_longitude , bike_id , user_type , member_birth_year , member_gender , bike_share_for_all_trip)
#
# Most of the variables are numerical<br>
# Rest of them are categorical
#
# **user_type**: Customer/Subscriber <br>
# **member_gender**: Male/Female "Other" will be dropped in future steps <br>
# **bike_share_for_all_trip**: No/Yes

# %% [markdown]
# ### Main feature of interest?
# The most feature I am intersested to investigate is "Duration" for rented bikes.

# %% [markdown]
# ### Features in the dataset I think will help support my feature investigation of interest?

# %% [markdown]
# I expect there might be a specific features will have a strong correlation with time spent such as gender , birth_year & type of the user. <br>
# Other features may impact the rent duration of bike as start & end stations.

# %% [markdown]
# ## 2. Data Cleaning & Preperation

# %% [markdown]
# ### 2.1 Dropping NaN's

# %%
#Checking for NAN values
df.isna().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %%
df[df['member_gender'].isna()]
# Out:
#         duration_sec                start_time                  end_time  \
# 1              42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 13               915  2019-02-28 23:49:06.0620  2019-03-01 00:04:21.8670
# 28               650  2019-02-28 23:43:27.5030  2019-02-28 23:54:18.4510
# 53              3418  2019-02-28 22:41:16.3620  2019-02-28 23:38:14.3630
# 65               926  2019-02-28 23:17:05.8530  2019-02-28 23:32:32.6820
# 147              372  2019-02-28 22:46:19.1140  2019-02-28 22:52:31.4770
# 176              730  2019-02-28 22:28:50.5140  2019-02-28 22:41:00.8970
# 220             1425  2019-02-28 22:05:25.5530  2019-02-28 22:29:11.1180
# 266             1302  2019-02-28 21:53:13.2740  2019-02-28 22:14:56.1730
# 292             1468  2019-02-28 21:43:04.3630  2019-02-28 22:07:32.6640
# 323              275  2019-02-28 21:52:54.9590  2019-02-28 21:57:30.5860
# 329              614  2019-02-28 21:45:47.5210  2019-02-28 21:56:02.0820
# 369              784  2019-02-28 21:34:04.0330  2019-02-28 21:47:08.2180
# 371              320  2019-02-28 21:41:14.0510  2019-02-28 21:46:34.7440
# 407              382  2019-02-28 21:32:00.4030  2019-02-28 21:38:22.9040
# 422              462  2019-02-28 21:28:29.4510  2019-02-28 21:36:11.4770
# 456              595  2019-02-28 21:18:14.9580  2019-02-28 21:28:10.3180
# 472              476  2019-02-28 21:16:42.8680  2019-02-28 21:24:39.8500
# 513              276  2019-02-28 21:14:26.2530  2019-02-28 21:19:02.7090
# 546            22087  2019-02-28 15:05:22.4670  2019-02-28 21:13:29.6710
# 547             1224  2019-02-28 20:52:59.8810  2019-02-28 21:13:24.1490
# 559              427  2019-02-28 21:04:38.5970  2019-02-28 21:11:45.8590
# 617             1259  2019-02-28 20:38:39.5600  2019-02-28 20:59:38.9710
# 641              502  2019-02-28 20:47:29.2170  2019-02-28 20:55:52.1840
# 703              604  2019-02-28 20:35:31.5170  2019-02-28 20:45:35.9980
# 726              150  2019-02-28 20:40:29.8530  2019-02-28 20:42:59.9050
# 768              472  2019-02-28 20:27:34.9640  2019-02-28 20:35:26.9640
# 777              847  2019-02-28 20:19:22.6330  2019-02-28 20:33:30.0630
# 778              537  2019-02-28 20:24:29.6360  2019-02-28 20:33:27.1260
# 786              305  2019-02-28 20:27:15.4070  2019-02-28 20:32:20.4740
# ...              ...                       ...                       ...
# 182896           819  2019-02-01 07:30:27.7900  2019-02-01 07:44:06.8310
# 182904           460  2019-02-01 07:35:23.2890  2019-02-01 07:43:04.1250
# 182919          1174  2019-02-01 07:21:29.5150  2019-02-01 07:41:04.0500
# 182951           181  2019-02-01 07:33:59.0810  2019-02-01 07:37:00.3560
# 182991          1156  2019-02-01 07:12:35.5660  2019-02-01 07:31:51.6390
# 183019           319  2019-02-01 07:22:45.2490  2019-02-01 07:28:05.1150
# 183077           455  2019-02-01 07:11:09.4440  2019-02-01 07:18:45.1520
# 183104          1136  2019-02-01 06:53:20.9500  2019-02-01 07:12:17.0780
# 183112           714  2019-02-01 06:57:46.6320  2019-02-01 07:09:41.2890
# 183126           354  2019-02-01 06:58:52.7650  2019-02-01 07:04:47.0170
# 183131           336  2019-02-01 06:58:14.2290  2019-02-01 07:03:50.8770
# 183135           582  2019-02-01 06:53:16.7010  2019-02-01 07:02:58.9480
# 183164           485  2019-02-01 06:46:56.0210  2019-02-01 06:55:01.8930
# 183180           187  2019-02-01 06:47:31.8750  2019-02-01 06:50:38.9200
# 183194           508  2019-02-01 06:38:01.6770  2019-02-01 06:46:29.8910
# 183198            68  2019-02-01 06:44:03.6380  2019-02-01 06:45:12.4190
# 183209           306  2019-02-01 06:36:23.4240  2019-02-01 06:41:29.7440
# 183212           679  2019-02-01 06:29:10.9000  2019-02-01 06:40:30.7640
# 183215         17953  2019-02-01 01:39:13.0980  2019-02-01 06:38:26.6810
# 183226           509  2019-02-01 06:25:20.7950  2019-02-01 06:33:50.5210
# 183281           677  2019-02-01 05:37:59.0090  2019-02-01 05:49:16.4370
# 183286           719  2019-02-01 05:30:42.6840  2019-02-01 05:42:41.7100
# 183306         13251  2019-02-01 01:03:11.3620  2019-02-01 04:44:03.3210
# 183310          1450  2019-02-01 03:17:02.2330  2019-02-01 03:41:12.3720
# 183332           828  2019-02-01 02:10:37.3200  2019-02-01 02:24:25.6090
# 183354           449  2019-02-01 01:35:07.6630  2019-02-01 01:42:36.8780
# 183356           795  2019-02-01 01:25:50.3660  2019-02-01 01:39:05.9500
# 183363           673  2019-02-01 01:12:24.4200  2019-02-01 01:23:37.6450
# 183371           196  2019-02-01 01:08:38.6410  2019-02-01 01:11:54.9490
# 183402           122  2019-02-01 00:17:32.2580  2019-02-01 00:19:34.9380
#
#         start_station_id                                 start_station_name  \
# 1                   23.0                      The Embarcadero at Steuart St
# 13                 252.0                       Channing Way at Shattuck Ave
# 28                 258.0                        University Ave at Oxford St
# 53                  11.0                             Davis St at Jackson St
# 65                  13.0                     Commercial St at Montgomery St
# 147                369.0                                 Hyde St at Post St
# 176                263.0                      Channing Way at San Pablo Ave
# 220                  8.0                      The Embarcadero at Vallejo St
# 266                181.0                            Grand Ave at Webster St
# 292                321.0                                   5th St at Folsom
# 323                198.0                                          Snow Park
# 329                 98.0                             Valencia St at 16th St
# 369                 44.0  Civic Center/UN Plaza BART Station (Market St ...
# 371                252.0                       Channing Way at Shattuck Ave
# 407                 50.0                              2nd St at Townsend St
# 422                285.0                         Webster St at O'Farrell St
# 456                 61.0                                Howard St at 8th St
# 472                197.0                        El Embarcadero at Grand Ave
# 513                365.0                             Turk St at Fillmore St
# 546                  3.0       Powell St BART Station (Market St at 4th St)
# 547                  6.0                      The Embarcadero at Sansome St
# 559                370.0                                Jones St at Post St
# 617                355.0                            23rd St at Tennessee St
# 641                 85.0                            Church St at Duboce Ave
# 703                125.0                               20th St at Bryant St
# 726                112.0                             Harrison St at 17th St
# 768                 21.0   Montgomery St BART Station (Market St at 2nd St)
# 777                108.0                               16th St Mission BART
# 778                201.0                               10th St at Fallon St
# 786                 44.0  Civic Center/UN Plaza BART Station (Market St ...
# ...                  ...                                                ...
# 182896              74.0                              Laguna St at Hayes St
# 182904              22.0                              Howard St at Beale St
# 182919             267.0                            Derby St at College Ave
# 182951              91.0                                Berry St at King St
# 182991             146.0                            30th St at San Jose Ave
# 183019             195.0                                Bay Pl at Vernon St
# 183077              86.0                            Market St at Dolores St
# 183104             144.0                                       Precita Park
# 183112              16.0                            Steuart St at Market St
# 183126              67.0  San Francisco Caltrain Station 2  (Townsend St...
# 183131               4.0                        Cyril Magnin St at Ellis St
# 183135             124.0                              19th St at Florida St
# 183164             381.0                              20th St at Dolores St
# 183180             102.0                                 Irwin St at 8th St
# 183194             304.0                               Jackson St at 5th St
# 183198             345.0                              Hubbell St at 16th St
# 183209             113.0                                    Franklin Square
# 183212             285.0                         Webster St at O'Farrell St
# 183215              86.0                            Market St at Dolores St
# 183226              58.0                               Market St at 10th St
# 183281              59.0                        S Van Ness Ave at Market St
# 183286              27.0                            Beale St at Harrison St
# 183306              31.0                         Raymond Kimbell Playground
# 183310               4.0                        Cyril Magnin St at Ellis St
# 183332             133.0                             Valencia St at 22nd St
# 183354             244.0                         Shattuck Ave at Hearst Ave
# 183356             368.0                               Myrtle St at Polk St
# 183363              75.0                           Market St at Franklin St
# 183371              58.0                               Market St at 10th St
# 183402             119.0                                  18th St at Noe St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 1                    37.791464              -122.391034            81.0
# 13                   37.865847              -122.267443           244.0
# 28                   37.872355              -122.266447           263.0
# 53                   37.797280              -122.398436            11.0
# 65                   37.794231              -122.402923            81.0
# 147                  37.787349              -122.416651            43.0
# 176                  37.862827              -122.290230           258.0
# 220                  37.799953              -122.398525           109.0
# 266                  37.811377              -122.265192           158.0
# 292                  37.780146              -122.403071            29.0
# 323                  37.807813              -122.264496           196.0
# 329                  37.765052              -122.421866           139.0
# 369                  37.781074              -122.411738            26.0
# 371                  37.865847              -122.267443           244.0
# 407                  37.780526              -122.390288            21.0
# 422                  37.783521              -122.431158           370.0
# 456                  37.776513              -122.411306            67.0
# 472                  37.808848              -122.249680           180.0
# 513                  37.780450              -122.431946            85.0
# 546                  37.786375              -122.404904           371.0
# 547                  37.804770              -122.403234            78.0
# 559                  37.787327              -122.413278           285.0
# 617                  37.755367              -122.388795            49.0
# 641                  37.770083              -122.429156           124.0
# 703                  37.759200              -122.409851           147.0
# 726                  37.763847              -122.413004           125.0
# 768                  37.789625              -122.400811            28.0
# 777                  37.764710              -122.419957           285.0
# 778                  37.797673              -122.262997           196.0
# 786                  37.781074              -122.411738            58.0
# ...                        ...                      ...             ...
# 182896               37.776435              -122.426244            21.0
# 182904               37.789756              -122.394643            10.0
# 182919               37.861804              -122.253569             7.0
# 182951               37.771762              -122.398438            79.0
# 182991               37.742314              -122.423180            29.0
# 183019               37.812314              -122.260779           182.0
# 183077               37.769305              -122.426826            42.0
# 183104               37.747300              -122.411403            26.0
# 183112               37.794130              -122.394430           104.0
# 183126               37.776639              -122.395526            27.0
# 183131               37.785881              -122.408915            17.0
# 183135               37.760447              -122.410807            67.0
# 183164               37.758238              -122.426094           133.0
# 183180               37.766883              -122.399579           104.0
# 183194               37.348759              -121.894798           312.0
# 183198               37.766483              -122.398279           102.0
# 183209               37.764555              -122.410345           345.0
# 183212               37.783521              -122.431158             5.0
# 183215               37.769305              -122.426826           356.0
# 183226               37.776619              -122.417385           133.0
# 183281               37.774814              -122.418954            16.0
# 183286               37.788059              -122.391865            58.0
# 183306               37.783813              -122.434559            13.0
# 183310               37.785881              -122.408915           321.0
# 183332               37.755213              -122.420975            58.0
# 183354               37.873676              -122.268487           253.0
# 183356               37.785434              -122.419622           125.0
# 183363               37.773793              -122.421239           133.0
# 183371               37.776619              -122.417385            75.0
# 183402               37.761047              -122.432642           120.0
#
#                                          end_station_name  \
# 1                                      Berry St at 4th St
# 13                             Shattuck Ave at Hearst Ave
# 28                          Channing Way at San Pablo Ave
# 53                                 Davis St at Jackson St
# 65                                     Berry St at 4th St
# 147     San Francisco Public Library (Grove St at Hyde...
# 176                           University Ave at Oxford St
# 220                                17th St at Valencia St
# 266                         Shattuck Ave at Telegraph Ave
# 292                         O'Farrell St at Divisadero St
# 323                               Grand Ave at Perkins St
# 329              Garfield Square (25th St at Harrison St)
# 369                                   1st St at Folsom St
# 371                            Shattuck Ave at Hearst Ave
# 407      Montgomery St BART Station (Market St at 2nd St)
# 422                                   Jones St at Post St
# 456     San Francisco Caltrain Station 2  (Townsend St...
# 472                              Telegraph Ave at 23rd St
# 513                               Church St at Duboce Ave
# 546                            Lombard St at Columbus Ave
# 547                                   Folsom St at 9th St
# 559                            Webster St at O'Farrell St
# 617                                   S Park St at 3rd St
# 641                                 19th St at Florida St
# 703                                29th St at Tiffany Ave
# 726                                  20th St at Bryant St
# 768                          The Embarcadero at Bryant St
# 777                            Webster St at O'Farrell St
# 778                               Grand Ave at Perkins St
# 786                                  Market St at 10th St
# ...                                                   ...
# 182896   Montgomery St BART Station (Market St at 2nd St)
# 182904                         Washington St at Kearny St
# 182919                                Frank H Ogawa Plaza
# 182951                               7th St at Brannan St
# 182991                      O'Farrell St at Divisadero St
# 183019                           19th Street BART Station
# 183077      San Francisco City Hall (Polk St at Grove St)
# 183104                                1st St at Folsom St
# 183112                                  4th St at 16th St
# 183126                            Beale St at Harrison St
# 183131   Embarcadero BART Station (Beale St at Market St)
# 183135  San Francisco Caltrain Station 2  (Townsend St...
# 183164                             Valencia St at 22nd St
# 183180                                  4th St at 16th St
# 183194                           San Jose Diridon Station
# 183198                                 Irwin St at 8th St
# 183209                              Hubbell St at 16th St
# 183212       Powell St BART Station (Market St at 5th St)
# 183215                        Valencia St at Clinton Park
# 183226                             Valencia St at 22nd St
# 183281                            Steuart St at Market St
# 183286                               Market St at 10th St
# 183306                     Commercial St at Montgomery St
# 183310                                   5th St at Folsom
# 183332                               Market St at 10th St
# 183354                            Haste St at College Ave
# 183356                               20th St at Bryant St
# 183363                             Valencia St at 22nd St
# 183371                           Market St at Franklin St
# 183402                               Mission Dolores Park
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 1                  37.775880            -122.393170     2535    Customer
# 13                 37.873676            -122.268487     5101  Subscriber
# 28                 37.862827            -122.290230     4784    Customer
# 53                 37.797280            -122.398436      319    Customer
# 65                 37.775880            -122.393170     2951  Subscriber
# 147                37.778768            -122.415929     2191    Customer
# 176                37.872355            -122.266447     4784    Customer
# 220                37.763316            -122.421904     6525  Subscriber
# 266                37.833279            -122.263490     2471    Customer
# 292                37.782405            -122.439446     6040    Customer
# 323                37.808894            -122.256460     2733  Subscriber
# 329                37.751017            -122.411901     6498    Customer
# 369                37.787290            -122.394380     4930  Subscriber
# 371                37.873676            -122.268487     4509    Customer
# 407                37.789625            -122.400811     6577  Subscriber
# 422                37.787327            -122.413278     5536  Subscriber
# 456                37.776639            -122.395526     1896  Subscriber
# 472                37.812678            -122.268773     4485    Customer
# 513                37.770083            -122.429156     5573  Subscriber
# 546                37.802746            -122.413579     2761    Customer
# 547                37.773717            -122.411647     4804  Subscriber
# 559                37.783521            -122.431158     4933  Subscriber
# 617                37.780760            -122.394989     2138    Customer
# 641                37.760447            -122.410807     5137    Customer
# 703                37.744067            -122.421472     4517    Customer
# 726                37.759200            -122.409851     3443  Subscriber
# 768                37.787168            -122.388098     2032  Subscriber
# 777                37.783521            -122.431158     3027    Customer
# 778                37.808894            -122.256460     3315    Customer
# 786                37.776619            -122.417385     4827  Subscriber
# ...                      ...                    ...      ...         ...
# 182896             37.789625            -122.400811     5543  Subscriber
# 182904             37.795393            -122.404770     1195  Subscriber
# 182919             37.804562            -122.271738     4898    Customer
# 182951             37.773492            -122.403673     5561  Subscriber
# 182991             37.782405            -122.439446     5011    Customer
# 183019             37.809013            -122.268247      107  Subscriber
# 183077             37.778650            -122.418230     5571    Customer
# 183104             37.787290            -122.394380     4738  Subscriber
# 183112             37.767045            -122.390833     5098    Customer
# 183126             37.788059            -122.391865     4924  Subscriber
# 183131             37.792251            -122.397086     1475  Subscriber
# 183135             37.776639            -122.395526     4964  Subscriber
# 183164             37.755213            -122.420975     5048    Customer
# 183180             37.767045            -122.390833     4369  Subscriber
# 183194             37.329732            -121.901782     3788  Subscriber
# 183198             37.766883            -122.399579      600  Subscriber
# 183209             37.766483            -122.398279     1100  Subscriber
# 183212             37.783899            -122.408445     5268  Subscriber
# 183215             37.769188            -122.422285     2947    Customer
# 183226             37.755213            -122.420975     5166  Subscriber
# 183281             37.794130            -122.394430     5029  Subscriber
# 183286             37.776619            -122.417385     1718  Subscriber
# 183306             37.794231            -122.402923     4889    Customer
# 183310             37.780146            -122.403071     2052    Customer
# 183332             37.776619            -122.417385     4962    Customer
# 183354             37.866418            -122.253799     5430    Customer
# 183356             37.759200            -122.409851     5400  Subscriber
# 183363             37.755213            -122.420975     5166    Customer
# 183371             37.773793            -122.421239     2395    Customer
# 183402             37.761420            -122.426435     4326  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 1                     NaN           NaN                      No
# 13                    NaN           NaN                      No
# 28                    NaN           NaN                      No
# 53                    NaN           NaN                      No
# 65                    NaN           NaN                      No
# 147                   NaN           NaN                      No
# 176                   NaN           NaN                      No
# 220                   NaN           NaN                      No
# 266                   NaN           NaN                      No
# 292                   NaN           NaN                      No
# 323                   NaN           NaN                      No
# 329                   NaN           NaN                      No
# 369                   NaN           NaN                      No
# 371                   NaN           NaN                      No
# 407                   NaN           NaN                      No
# 422                   NaN           NaN                      No
# 456                   NaN           NaN                      No
# 472                   NaN           NaN                      No
# 513                   NaN           NaN                      No
# 546                   NaN           NaN                      No
# 547                   NaN           NaN                      No
# 559                   NaN           NaN                      No
# 617                   NaN           NaN                      No
# 641                   NaN           NaN                      No
# 703                   NaN           NaN                      No
# 726                   NaN           NaN                      No
# 768                   NaN           NaN                      No
# 777                   NaN           NaN                      No
# 778                   NaN           NaN                      No
# 786                   NaN           NaN                      No
# ...                   ...           ...                     ...
# 182896                NaN           NaN                      No
# 182904                NaN           NaN                      No
# 182919                NaN           NaN                      No
# 182951                NaN           NaN                      No
# 182991                NaN           NaN                      No
# 183019                NaN           NaN                      No
# 183077                NaN           NaN                      No
# 183104                NaN           NaN                      No
# 183112                NaN           NaN                      No
# 183126                NaN           NaN                      No
# 183131                NaN           NaN                      No
# 183135                NaN           NaN                      No
# 183164                NaN           NaN                      No
# 183180                NaN           NaN                      No
# 183194                NaN           NaN                      No
# 183198                NaN           NaN                      No
# 183209                NaN           NaN                      No
# 183212                NaN           NaN                      No
# 183215                NaN           NaN                      No
# 183226                NaN           NaN                      No
# 183281                NaN           NaN                      No
# 183286                NaN           NaN                      No
# 183306                NaN           NaN                      No
# 183310                NaN           NaN                      No
# 183332                NaN           NaN                      No
# 183354                NaN           NaN                      No
# 183356                NaN           NaN                      No
# 183363                NaN           NaN                      No
# 183371                NaN           NaN                      No
# 183402                NaN           NaN                      No
#
# [8265 rows x 16 columns]

# %%
#Dropping NaN's in most important features for me
df.dropna(subset=['member_birth_year'],inplace=True)
df.dropna(subset=['member_gender'],inplace=True)

# %%
#Rechecking for NaN values for most important features
df.isna().sum()
# Out:
# duration_sec                 0
# start_time                   0
# end_time                     0
# start_station_id           195
# start_station_name         195
# start_station_latitude       0
# start_station_longitude      0
# end_station_id             195
# end_station_name           195
# end_station_latitude         0
# end_station_longitude        0
# bike_id                      0
# user_type                    0
# member_birth_year            0
# member_gender                0
# bike_share_for_all_trip      0
# dtype: int64

# %%
#Rechecking the shape
df.shape
# Out:
# (175147, 16)

# %%
#Making Sure that both features 'start_station_name'  &  'end_station_name' have NaN in same row
df[df.start_station_name.isna() & df.end_station_name.isna()].shape[0]
# Out:
# 195

# %%
df.dropna(subset=['start_station_name'],inplace=True)
df.dropna(subset=['end_station_name'],inplace=True)

# %%
#Rechecking for NaN values for most important features
df.isna().sum()
# Out:
# duration_sec               0
# start_time                 0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# bike_id                    0
# user_type                  0
# member_birth_year          0
# member_gender              0
# bike_share_for_all_trip    0
# dtype: int64

# %%
#Rechecking the shape
df.shape
# Out:
# (174952, 16)

# %% [markdown]
# ### 2.2 Dropping 'Other' gender

# %% [markdown]
# It is somehow confusing to keep it in data as gender will be important independant feature to work on.

# %%
df[df.member_gender == 'Other']
# Out:
#         duration_sec                start_time                  end_time  \
# 3              36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 8               1570  2019-02-28 23:41:48.7900  2019-03-01 00:07:59.7150
# 131             1187  2019-02-28 22:39:58.5600  2019-02-28 22:59:46.2060
# 135              544  2019-02-28 22:48:12.7300  2019-02-28 22:57:17.0800
# 190              515  2019-02-28 22:28:11.3470  2019-02-28 22:36:46.3890
# 231              244  2019-02-28 22:21:46.8260  2019-02-28 22:25:51.2500
# 261              748  2019-02-28 22:03:01.7060  2019-02-28 22:15:30.3670
# 710              485  2019-02-28 20:36:18.5170  2019-02-28 20:44:23.6630
# 798              975  2019-02-28 20:13:20.5050  2019-02-28 20:29:35.6690
# 827              352  2019-02-28 20:19:41.5110  2019-02-28 20:25:34.1210
# 887              542  2019-02-28 20:09:07.2530  2019-02-28 20:18:09.8540
# 892              655  2019-02-28 20:05:55.8520  2019-02-28 20:16:51.3700
# 919             1264  2019-02-28 19:52:28.8720  2019-02-28 20:13:33.5370
# 922              753  2019-02-28 20:00:40.3760  2019-02-28 20:13:13.8190
# 928              291  2019-02-28 20:07:34.9590  2019-02-28 20:12:26.3480
# 1075             415  2019-02-28 19:47:39.8680  2019-02-28 19:54:35.0390
# 1087             537  2019-02-28 19:44:08.8290  2019-02-28 19:53:06.1610
# 1106             851  2019-02-28 19:36:45.2310  2019-02-28 19:50:57.0650
# 1123             366  2019-02-28 19:42:18.5310  2019-02-28 19:48:25.2980
# 1176            1484  2019-02-28 19:17:32.4590  2019-02-28 19:42:17.3290
# 1211             617  2019-02-28 19:27:34.8010  2019-02-28 19:37:52.0150
# 1394             752  2019-02-28 19:09:18.0740  2019-02-28 19:21:50.7520
# 1419             517  2019-02-28 19:09:49.1890  2019-02-28 19:18:26.3200
# 1432             398  2019-02-28 19:09:44.2940  2019-02-28 19:16:23.2800
# 1560             614  2019-02-28 18:55:29.1720  2019-02-28 19:05:43.9160
# 1633            1138  2019-02-28 18:41:23.8310  2019-02-28 19:00:22.3990
# 1654             632  2019-02-28 18:48:30.4750  2019-02-28 18:59:03.1160
# 1672            1069  2019-02-28 18:39:58.7280  2019-02-28 18:57:48.0510
# 1756             857  2019-02-28 18:37:55.3430  2019-02-28 18:52:12.5530
# 1777             356  2019-02-28 18:44:36.8080  2019-02-28 18:50:33.1790
# ...              ...                       ...                       ...
# 181369           306  2019-02-01 09:17:25.0870  2019-02-01 09:22:32.0820
# 181455           286  2019-02-01 09:13:53.3180  2019-02-01 09:18:39.7440
# 181490           621  2019-02-01 09:06:32.2070  2019-02-01 09:16:53.5050
# 181573           597  2019-02-01 09:01:42.4820  2019-02-01 09:11:39.7980
# 181606           270  2019-02-01 09:05:37.5030  2019-02-01 09:10:07.7910
# 181652           598  2019-02-01 08:57:44.4730  2019-02-01 09:07:43.0910
# 181780          1385  2019-02-01 08:38:22.1440  2019-02-01 09:01:27.9350
# 181909            73  2019-02-01 08:52:29.6030  2019-02-01 08:53:43.4490
# 181940           585  2019-02-01 08:42:09.2220  2019-02-01 08:51:54.6490
# 181963           262  2019-02-01 08:46:02.9160  2019-02-01 08:50:24.9490
# 181981           341  2019-02-01 08:44:01.6170  2019-02-01 08:49:42.6430
# 181986          2055  2019-02-01 08:15:14.4760  2019-02-01 08:49:30.1860
# 182133          6086  2019-02-01 07:00:02.0420  2019-02-01 08:41:28.2510
# 182153          1280  2019-02-01 08:19:13.5950  2019-02-01 08:40:34.1650
# 182492           499  2019-02-01 08:12:24.7480  2019-02-01 08:20:44.3950
# 182560          1003  2019-02-01 07:59:39.1370  2019-02-01 08:16:22.9930
# 182661           410  2019-02-01 08:00:25.4420  2019-02-01 08:07:15.6860
# 182697           770  2019-02-01 07:50:46.6260  2019-02-01 08:03:37.4880
# 182738           665  2019-02-01 07:49:01.7650  2019-02-01 08:00:07.1230
# 182807           577  2019-02-01 07:45:09.5210  2019-02-01 07:54:47.3830
# 182871           397  2019-02-01 07:40:49.9320  2019-02-01 07:47:27.2310
# 183060          1616  2019-02-01 06:54:49.0400  2019-02-01 07:21:45.6570
# 183075           332  2019-02-01 07:13:17.7140  2019-02-01 07:18:50.2980
# 183228           192  2019-02-01 06:30:18.3140  2019-02-01 06:33:30.4480
# 183309          1099  2019-02-01 03:23:23.2050  2019-02-01 03:41:42.5910
# 183346           312  2019-02-01 02:06:04.5660  2019-02-01 02:11:17.1220
# 183349           527  2019-02-01 01:48:54.7550  2019-02-01 01:57:42.5400
# 183378           659  2019-02-01 00:53:36.1430  2019-02-01 01:04:35.3710
# 183381           426  2019-02-01 00:48:54.1590  2019-02-01 00:56:00.4740
# 183389           184  2019-02-01 00:43:56.5560  2019-02-01 00:47:01.0090
#
#         start_station_id                                 start_station_name  \
# 3                  375.0                            Grove St at Masonic Ave
# 8                   10.0                         Washington St at Kearny St
# 131                262.0                          West St at University Ave
# 135                356.0                        Valencia St at Clinton Park
# 190                 58.0                               Market St at 10th St
# 231                 75.0                           Market St at Franklin St
# 261                 74.0                              Laguna St at Hayes St
# 710                181.0                            Grand Ave at Webster St
# 798                156.0                          Stanford Ave at Hollis St
# 827                163.0                          Lake Merritt BART Station
# 887                258.0                        University Ave at Oxford St
# 892                 41.0                         Golden Gate Ave at Polk St
# 919                176.0                             MacArthur BART Station
# 922                 76.0                         McCoppin St at Valencia St
# 928                223.0                     16th St Mission BART Station 2
# 1075               323.0                                 Broadway at Kearny
# 1087               258.0                        University Ave at Oxford St
# 1106                67.0  San Francisco Caltrain Station 2  (Townsend St...
# 1123               160.0                          West Oakland BART Station
# 1176                21.0   Montgomery St BART Station (Market St at 2nd St)
# 1211               349.0                               Howard St at Mary St
# 1394                 6.0                      The Embarcadero at Sansome St
# 1419                 4.0                        Cyril Magnin St at Ellis St
# 1432                 3.0       Powell St BART Station (Market St at 4th St)
# 1560               150.0                              Adeline St at 40th St
# 1633               187.0                                 Jack London Square
# 1654                47.0                              4th St at Harrison St
# 1672               176.0                             MacArthur BART Station
# 1756               197.0                        El Embarcadero at Grand Ave
# 1777               104.0                                  4th St at 16th St
# ...                  ...                                                ...
# 181369             106.0                              Sanchez St at 17th St
# 181455              80.0                              Townsend St at 5th St
# 181490             350.0                               8th St at Brannan St
# 181573             200.0                               2nd Ave at E 18th St
# 181606             267.0                            Derby St at College Ave
# 181652             171.0                             Rockridge BART Station
# 181780             270.0                              Ninth St at Heinz Ave
# 181909             253.0                            Haste St at College Ave
# 181940             110.0   17th & Folsom Street Park (17th St at Folsom St)
# 181963              18.0                      Telegraph Ave at Alcatraz Ave
# 181981             274.0                            Oregon St at Adeline St
# 181986             193.0                       Grand Ave at Santa Clara Ave
# 182133             380.0                             Masonic Ave at Turk St
# 182153             166.0                        College Ave at Alcatraz Ave
# 182492             159.0                               24th St at Market St
# 182560             246.0                              Berkeley Civic Center
# 182661             180.0                           Telegraph Ave at 23rd St
# 182697              96.0                              Dolores St at 15th St
# 182738             204.0                           55th St at Telegraph Ave
# 182807             214.0                         Market St at Brockhurst St
# 182871              61.0                                Howard St at 8th St
# 183060              85.0                            Church St at Duboce Ave
# 183075             250.0                        North Berkeley BART Station
# 183228             321.0                                   5th St at Folsom
# 183309             166.0                        College Ave at Alcatraz Ave
# 183346             175.0                           49th St at Telegraph Ave
# 183349             213.0                              32nd St at Adeline St
# 183378              47.0                              4th St at Harrison St
# 183381             230.0                            14th St at Mandela Pkwy
# 183389              66.0                              3rd St at Townsend St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 3                    37.774836              -122.446546            70.0
# 8                    37.795393              -122.404770           127.0
# 131                  37.869967              -122.286533           240.0
# 135                  37.769188              -122.422285            34.0
# 190                  37.776619              -122.417385           321.0
# 231                  37.773793              -122.421239            58.0
# 261                  37.776435              -122.426244            30.0
# 710                  37.811377              -122.265192           193.0
# 798                  37.838443              -122.288665           232.0
# 827                  37.797320              -122.265320           200.0
# 887                  37.872355              -122.266447           258.0
# 892                  37.781270              -122.418740            39.0
# 919                  37.828410              -122.266315           156.0
# 922                  37.771662              -122.422423           323.0
# 928                  37.764765              -122.420091            86.0
# 1075                 37.798014              -122.405950            21.0
# 1087                 37.872355              -122.266447           258.0
# 1106                 37.776639              -122.395526            74.0
# 1123                 37.805318              -122.294837           235.0
# 1176                 37.789625              -122.400811           134.0
# 1211                 37.781010              -122.405666           109.0
# 1394                 37.804770              -122.403234            81.0
# 1419                 37.785881              -122.408915           323.0
# 1432                 37.786375              -122.404904            67.0
# 1560                 37.831277              -122.278267           149.0
# 1633                 37.796248              -122.279352           315.0
# 1654                 37.780955              -122.399749           126.0
# 1672                 37.828410              -122.266315           207.0
# 1756                 37.808848              -122.249680           187.0
# 1777                 37.767045              -122.390833           115.0
# ...                        ...                      ...             ...
# 181369               37.763242              -122.430675           223.0
# 181455               37.775235              -122.397437           114.0
# 181490               37.771431              -122.405787            21.0
# 181573               37.800214              -122.253810             7.0
# 181606               37.861804              -122.253569           243.0
# 181652               37.844279              -122.251900           243.0
# 181780               37.853489              -122.289415             7.0
# 181909               37.866418              -122.253799           243.0
# 181940               37.763708              -122.415204           104.0
# 181963               37.850222              -122.260172           248.0
# 181981               37.857567              -122.267558           246.0
# 181986               37.812744              -122.247215           245.0
# 182133               37.779047              -122.447291           377.0
# 182153               37.851376              -122.252523             7.0
# 182492               37.816060              -122.278244           181.0
# 182560               37.869060              -122.270556           150.0
# 182661               37.812678              -122.268773           212.0
# 182697               37.766210              -122.426614            21.0
# 182738               37.840186              -122.261823           239.0
# 182807               37.823321              -122.275732           176.0
# 182871               37.776513              -122.411306            79.0
# 183060               37.770083              -122.429156            15.0
# 183075               37.873558              -122.283093           254.0
# 183228               37.780146              -122.403071             5.0
# 183309               37.851376              -122.252523           213.0
# 183346               37.835946              -122.262366           166.0
# 183349               37.823847              -122.281193           158.0
# 183378               37.780955              -122.399749            67.0
# 183381               37.810743              -122.291415           213.0
# 183389               37.778742              -122.392741            47.0
#
#                                          end_station_name  \
# 3                                  Central Ave at Fell St
# 8                                  Valencia St at 21st St
# 131                             Haste St at Telegraph Ave
# 135                        Father Alfred E Boeddeker Park
# 190                                      5th St at Folsom
# 231                                  Market St at 10th St
# 261        San Francisco Caltrain (Townsend St at 4th St)
# 710                          Grand Ave at Santa Clara Ave
# 798                                 MLK Jr Way at 14th St
# 827                                  2nd Ave at E 18th St
# 887                           University Ave at Oxford St
# 892                           Scott St at Golden Gate Ave
# 919                             Stanford Ave at Hollis St
# 922                                    Broadway at Kearny
# 928                               Market St at Dolores St
# 1075     Montgomery St BART Station (Market St at 2nd St)
# 1087                          University Ave at Oxford St
# 1106                                Laguna St at Hayes St
# 1123                                  Union St at 10th St
# 1176                               Valencia St at 24th St
# 1211                               17th St at Valencia St
# 1394                                   Berry St at 4th St
# 1419                                   Broadway at Kearny
# 1432    San Francisco Caltrain Station 2  (Townsend St...
# 1560                                 Emeryville Town Hall
# 1633                                 Market St at 45th St
# 1654                                          Esprit Park
# 1672                             Broadway at Coronado Ave
# 1756                                   Jack London Square
# 1777                                   Jackson Playground
# ...                                                   ...
# 181369                     16th St Mission BART Station 2
# 181455                         Rhode Island St at 17th St
# 181490   Montgomery St BART Station (Market St at 2nd St)
# 181573                                Frank H Ogawa Plaza
# 181606                        Bancroft Way at College Ave
# 181652                        Bancroft Way at College Ave
# 181780                                Frank H Ogawa Plaza
# 181909                        Bancroft Way at College Ave
# 181940                                  4th St at 16th St
# 181963                         Telegraph Ave at Ashby Ave
# 181981                              Berkeley Civic Center
# 181986                             Downtown Berkeley BART
# 182133                              Fell St at Stanyan St
# 182153                                Frank H Ogawa Plaza
# 182492                            Grand Ave at Webster St
# 182560                              Adeline St at 40th St
# 182661                                      Mosswood Park
# 182697   Montgomery St BART Station (Market St at 2nd St)
# 182738                      Bancroft Way at Telegraph Ave
# 182807                             MacArthur BART Station
# 182871                               7th St at Brannan St
# 183060  San Francisco Ferry Building (Harry Bridges Pl...
# 183075                            Vine St at Shattuck Ave
# 183228       Powell St BART Station (Market St at 5th St)
# 183309                              32nd St at Adeline St
# 183346                        College Ave at Alcatraz Ave
# 183349                      Shattuck Ave at Telegraph Ave
# 183378  San Francisco Caltrain Station 2  (Townsend St...
# 183381                              32nd St at Adeline St
# 183389                              4th St at Harrison St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 3                  37.773311            -122.444293     6638  Subscriber
# 8                  37.756708            -122.421025     6548  Subscriber
# 131                37.866043            -122.258804     5649  Subscriber
# 135                37.783988            -122.412408     6065  Subscriber
# 190                37.780146            -122.403071     5234  Subscriber
# 231                37.776619            -122.417385      481  Subscriber
# 261                37.776598            -122.395282     6520  Subscriber
# 710                37.812744            -122.247215     4579  Subscriber
# 798                37.806163            -122.276040     6060  Subscriber
# 827                37.800214            -122.253810     3505  Subscriber
# 887                37.872355            -122.266447      777  Subscriber
# 892                37.778999            -122.436861     5150  Subscriber
# 919                37.838443            -122.288665     2598  Subscriber
# 922                37.798014            -122.405950     6477  Subscriber
# 928                37.769305            -122.426826     6463  Subscriber
# 1075               37.789625            -122.400811     6381  Subscriber
# 1087               37.872355            -122.266447      777  Subscriber
# 1106               37.776435            -122.426244     4567  Subscriber
# 1123               37.807239            -122.289370     6392  Subscriber
# 1176               37.752428            -122.420628     2330  Subscriber
# 1211               37.763316            -122.421904     5037  Subscriber
# 1394               37.775880            -122.393170     4619  Subscriber
# 1419               37.798014            -122.405950     6381  Subscriber
# 1432               37.776639            -122.395526     2321  Subscriber
# 1560               37.831275            -122.285633     5514  Subscriber
# 1633               37.834174            -122.272968     4523  Subscriber
# 1654               37.761634            -122.390648     1475  Subscriber
# 1672               37.835788            -122.251621     6000  Subscriber
# 1756               37.796248            -122.279352     6408  Subscriber
# 1777               37.765026            -122.398773     1564  Subscriber
# ...                      ...                    ...      ...         ...
# 181369             37.764765            -122.420091     3359  Subscriber
# 181455             37.764478            -122.402570     5540  Subscriber
# 181490             37.789625            -122.400811     5045  Subscriber
# 181573             37.804562            -122.271738     1889  Subscriber
# 181606             37.869360            -122.254337      668  Subscriber
# 181652             37.869360            -122.254337     4588  Subscriber
# 181780             37.804562            -122.271738     5493    Customer
# 181909             37.869360            -122.254337     3232  Subscriber
# 181940             37.767045            -122.390833     4966  Subscriber
# 181963             37.855956            -122.259795     3471  Subscriber
# 181981             37.869060            -122.270556     4890    Customer
# 181986             37.870139            -122.268422      325  Subscriber
# 182133             37.771917            -122.453704     4956  Subscriber
# 182153             37.804562            -122.271738     4485  Subscriber
# 182492             37.811377            -122.265192     4543  Subscriber
# 182560             37.831277            -122.278267     3347  Subscriber
# 182661             37.824893            -122.260437     5499    Customer
# 182697             37.789625            -122.400811     5288  Subscriber
# 182738             37.868813            -122.258764     4581  Subscriber
# 182807             37.828410            -122.266315     2534  Subscriber
# 182871             37.773492            -122.403673     1841  Subscriber
# 183060             37.795392            -122.394203     5404  Subscriber
# 183075             37.880222            -122.269592     5111  Subscriber
# 183228             37.783899            -122.408445     5007  Subscriber
# 183309             37.823847            -122.281193     5450  Subscriber
# 183346             37.851376            -122.252523     5450  Subscriber
# 183349             37.833279            -122.263490     1172  Subscriber
# 183378             37.776639            -122.395526     4960  Subscriber
# 183381             37.823847            -122.281193     3535  Subscriber
# 183389             37.780955            -122.399749     4960  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 3                  1989.0         Other                      No
# 8                  1988.0         Other                      No
# 131                1993.0         Other                      No
# 135                1991.0         Other                      No
# 190                1981.0         Other                      No
# 231                1981.0         Other                      No
# 261                1985.0         Other                      No
# 710                1983.0         Other                      No
# 798                1982.0         Other                      No
# 827                1984.0         Other                      No
# 887                1987.0         Other                      No
# 892                1968.0         Other                      No
# 919                1963.0         Other                      No
# 922                1995.0         Other                     Yes
# 928                1976.0         Other                      No
# 1075               1976.0         Other                      No
# 1087               1987.0         Other                      No
# 1106               1985.0         Other                      No
# 1123               1990.0         Other                     Yes
# 1176               1986.0         Other                      No
# 1211               1996.0         Other                      No
# 1394               1983.0         Other                      No
# 1419               1976.0         Other                      No
# 1432               1985.0         Other                      No
# 1560               1987.0         Other                      No
# 1633               1964.0         Other                      No
# 1654               1980.0         Other                      No
# 1672               1985.0         Other                      No
# 1756               1993.0         Other                      No
# 1777               1984.0         Other                     Yes
# ...                   ...           ...                     ...
# 181369             1984.0         Other                      No
# 181455             1975.0         Other                      No
# 181490             1988.0         Other                      No
# 181573             1984.0         Other                      No
# 181606             1997.0         Other                     Yes
# 181652             1962.0         Other                      No
# 181780             1983.0         Other                      No
# 181909             1997.0         Other                     Yes
# 181940             1980.0         Other                      No
# 181963             1985.0         Other                      No
# 181981             1994.0         Other                      No
# 181986             1993.0         Other                      No
# 182133             1971.0         Other                      No
# 182153             1965.0         Other                      No
# 182492             1990.0         Other                      No
# 182560             1979.0         Other                      No
# 182661             1984.0         Other                      No
# 182697             1989.0         Other                      No
# 182738             1966.0         Other                      No
# 182807             1992.0         Other                      No
# 182871             1967.0         Other                      No
# 183060             1964.0         Other                     Yes
# 183075             1987.0         Other                      No
# 183228             1981.0         Other                      No
# 183309             1997.0         Other                     Yes
# 183346             1997.0         Other                     Yes
# 183349             1997.0         Other                     Yes
# 183378             1985.0         Other                      No
# 183381             1997.0         Other                     Yes
# 183389             1985.0         Other                      No
#
# [3647 rows x 16 columns]

# %%
#Dropping Other gender
df.drop(df.index[df['member_gender'] == 'Other'],inplace=True)

# %%
#Rechecking of Other gender
df[df.member_gender == 'Other']
# Out:
# Empty DataFrame
# Columns: [duration_sec, start_time, end_time, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bike_id, user_type, member_birth_year, member_gender, bike_share_for_all_trip]
# Index: []

# %% [markdown]
# ### 2.3 Changing datatype of 'start_time'  &  'end_time' to datetime

# %%
#Changing dtype of start & time from str obj  to  datetime
df.start_time = pd.to_datetime(df.start_time)
df.end_time = pd.to_datetime(df.end_time)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171305 entries, 0 to 183411
# Data columns (total 16 columns):
# duration_sec               171305 non-null int64
# start_time                 171305 non-null datetime64[ns]
# end_time                   171305 non-null datetime64[ns]
# start_station_id           171305 non-null float64
# start_station_name         171305 non-null object
# start_station_latitude     171305 non-null float64
# start_station_longitude    171305 non-null float64
# end_station_id             171305 non-null float64
# end_station_name           171305 non-null object
# end_station_latitude       171305 non-null float64
# end_station_longitude      171305 non-null float64
# bike_id                    171305 non-null int64
# user_type                  171305 non-null object
# member_birth_year          171305 non-null float64
# member_gender              171305 non-null object
# bike_share_for_all_trip    171305 non-null object
# dtypes: datetime64[ns](2), float64(7), int64(2), object(5)
# memory usage: 22.2+ MB

# %% [markdown]
# ### 2.4 Converting rent duration to min for better understanding

# %%
df['duration_min'] = df['duration_sec']/60
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 4          1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# 5          1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
# 6          1147 2019-02-28 23:55:35.104 2019-03-01 00:14:42.588
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 4               7.0                               Frank H Ogawa Plaza
# 5              93.0                      4th St at Mission Bay Blvd S
# 6             300.0                              Palm St at Willow St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 2               37.769305              -122.426826             3.0
# 4               37.804562              -122.271738           222.0
# 5               37.770407              -122.391198           323.0
# 6               37.317298              -121.884995           312.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 4                         10th Ave at E 15th St             37.792714
# 5                            Broadway at Kearny             37.798014
# 6                      San Jose Diridon Station             37.329732
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 2            -122.404904     5905    Customer             1972.0
# 4            -122.248780     4898  Subscriber             1974.0
# 5            -122.405950     5200  Subscriber             1959.0
# 6            -121.901782     3803  Subscriber             1983.0
#
#   member_gender bike_share_for_all_trip  duration_min
# 0          Male                      No    869.750000
# 2          Male                      No   1030.900000
# 4          Male                     Yes     26.416667
# 5          Male                      No     29.883333
# 6        Female                      No     19.116667

# %% [markdown]
# ### 2.5 Getting member age to use in analysis rather than member_birth_year

# %%
df['member_age'] = 2019 - df['member_birth_year']
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 4          1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# 5          1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
# 6          1147 2019-02-28 23:55:35.104 2019-03-01 00:14:42.588
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 4               7.0                               Frank H Ogawa Plaza
# 5              93.0                      4th St at Mission Bay Blvd S
# 6             300.0                              Palm St at Willow St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 2               37.769305              -122.426826             3.0
# 4               37.804562              -122.271738           222.0
# 5               37.770407              -122.391198           323.0
# 6               37.317298              -121.884995           312.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 4                         10th Ave at E 15th St             37.792714
# 5                            Broadway at Kearny             37.798014
# 6                      San Jose Diridon Station             37.329732
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 2            -122.404904     5905    Customer             1972.0
# 4            -122.248780     4898  Subscriber             1974.0
# 5            -122.405950     5200  Subscriber             1959.0
# 6            -121.901782     3803  Subscriber             1983.0
#
#   member_gender bike_share_for_all_trip  duration_min  member_age
# 0          Male                      No    869.750000        35.0
# 2          Male                      No   1030.900000        47.0
# 4          Male                     Yes     26.416667        45.0
# 5          Male                      No     29.883333        60.0
# 6        Female                      No     19.116667        36.0

# %% [markdown]
# ### 2.6 Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.7 Adding new columns "Day Start" & "Hour Start"

# %%
df["hour_start"] = df['start_time'].dt.hour
df["day_start"] = df['start_time'].dt.weekday_name
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 4          1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# 5          1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
# 6          1147 2019-02-28 23:55:35.104 2019-03-01 00:14:42.588
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 4               7.0                               Frank H Ogawa Plaza
# 5              93.0                      4th St at Mission Bay Blvd S
# 6             300.0                              Palm St at Willow St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 2               37.769305              -122.426826             3.0
# 4               37.804562              -122.271738           222.0
# 5               37.770407              -122.391198           323.0
# 6               37.317298              -121.884995           312.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 4                         10th Ave at E 15th St             37.792714
# 5                            Broadway at Kearny             37.798014
# 6                      San Jose Diridon Station             37.329732
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 2            -122.404904     5905    Customer             1972.0
# 4            -122.248780     4898  Subscriber             1974.0
# 5            -122.405950     5200  Subscriber             1959.0
# 6            -121.901782     3803  Subscriber             1983.0
#
#   member_gender bike_share_for_all_trip  duration_min  member_age  hour_start  \
# 0          Male                      No    869.750000        35.0          17
# 2          Male                      No   1030.900000        47.0          12
# 4          Male                     Yes     26.416667        45.0          23
# 5          Male                      No     29.883333        60.0          23
# 6        Female                      No     19.116667        36.0          23
#
#   day_start
# 0  Thursday
# 2  Thursday
# 4  Thursday
# 5  Thursday
# 6  Thursday

# %%
df.shape
# Out:
# (171305, 20)

# %% [markdown]
# ## 3. Univariate Exploration
#
# ### 3.1 Distribution of Trips Duration

# %%
bins = np.arange(0,df.duration_min.max()+10,10)
plt.figure(figsize=[12,8])
plt.hist(data=df,x='duration_min',bins=bins)
plt.title('Distribution of Trip Durations')
plt.xlabel('Duration (min)')
plt.ylabel('Trips Number')
plt.xlim([-100,900]);

# %% [markdown]
# ###### Beacause most of  data is concentrated in small region <br>logarthmic scall + clipping X-axis will be used to give better visulaization

# %%
#Getting logarithmic min & max
np.log(df['duration_min'].describe())
# Out:
# count    12.051201
# mean      2.453528
# std       3.269096
# min       0.016529
# 25%       1.680207
# 50%       2.138103
# 75%       2.573884
# max       7.250730
# Name: duration_min, dtype: float64

# %%
bins = 10 ** np.arange(-2,8+0.1,0.1)
plt.figure(figsize=[12,8])
plt.hist(data=df,x='duration_min',bins=bins)
plt.title('Distribution of Trip Durations')
plt.xlabel('Duration (min)')
plt.ylabel('Trips Number')
plt.xscale('log')
plt.xlim([0.1,1e4])
plt.xticks([0.1,0.5,1,5,10,5e1,1e2,5e2,1e3,5e3,1e4])
plt.yticks([0,2500,5000,7500,10000,12500,15000,17500,20000,22500,25000])
arrow_properties = dict(
    facecolor="red", width=5.5,
    headwidth=15, shrink=0.1)
plt.annotate('Outlier',xy=(1100,200),xytext=(800,5000),arrowprops=arrow_properties);

# %%
#Zooming in outlier region
bins = 10 ** np.arange(-2,8+0.1,0.1)
plt.hist(data=df,x='duration_min',bins=bins)
plt.title('Outliers Distribution of Trip Durations')
plt.xlabel('Duration (min)')
plt.ylabel('Trips Number')
plt.xscale('log')
plt.xlim([600,1500])
plt.ylim([0,200]);

# %% [markdown]
# ##### 1. The average time spent is about  10 min  <br> 2. Distribution is normally distributed as excpected <br> 3. There is an outlier where time spent is about 1000 min for very small number of trips (about 25 trips)

# %% [markdown]
# ### 3.2 Age Distribution

# %%
bins = np.arange(0,df.member_age.max()+2,2)
plt.figure(figsize=[12,8])
plt.hist(data=df,x='member_age',bins=bins)
plt.title('Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Count')
#plt.xlim([-100,900]);
arrow_properties = dict(
    facecolor="red", width=5.5,
    headwidth=15, shrink=0.1)
plt.annotate('Outlier',xy=(120,200),xytext=(100,4000),arrowprops=arrow_properties);

# %% [markdown]
# ##### - It seems that average users who makes a ride is about 34 year.<br> - There is outlier with age value 120 year which seems to be strange, a result of that might be random entery may happened when collecting data

# %% [markdown]
# ### 3.3 Gender & Customer type Distribution

# %%
gender_no = df.member_gender.value_counts()
user_no = df.user_type.value_counts()

plt.figure(figsize=[12,8])
plt.subplot(1,2,1)
plt.bar(x=gender_no.keys(),height=gender_no)
plt.title('Gender Distribution')
plt.xlabel('Gender Type')
plt.ylabel('Number of Gender')

plt.subplot(1,2,2)
plt.bar(x=user_no.keys(),height=user_no)
plt.title('User Type Distribution')
plt.xlabel('User Type')
plt.ylabel('Number of Users')
# Out:
# Text(0,0.5,'Number of Users')

# %%
#Same as above, but using proption rather than distribution
plt.figure(figsize=[12,8])

plt.subplot(1,2,1)
plt.pie(gender_no,labels=gender_no.index,startangle=90,autopct = '%1.2f%%',shadow = True,textprops = {"fontsize":15})
plt.title('Gender Proption')
plt.axis('equal')


plt.subplot(1,2,2)
plt.pie(user_no,labels=user_no.index,startangle=90,autopct = '%1.2f%%',shadow = True,textprops = {"fontsize":15})
plt.title('User Type Proption')
plt.axis('equal');

# %% [markdown]
# #### 3.3.0 Subscribed No vs Customer No for each gender

# %%
#Subscribed No for each gender
sub_filt = df[df['user_type'] == 'Subscriber']
cust_filt = df[df['user_type'] == 'Customer']
gender_sub_no = sub_filt.member_gender.value_counts()
gender_cust_no = cust_filt.member_gender.value_counts()

plt.figure(figsize=[12,8])

#Subscribed No for each gender
plt.subplot(1,2,1)
plt.bar(x = gender_sub_no.keys(),height=gender_sub_no)
plt.title('Gender Subscriber Distribution')
plt.xlabel('Gender Type')
plt.ylabel('Number of Gender subscribed')

#Customer No for each gender
plt.subplot(1,2,2)
plt.bar(x = gender_cust_no.keys(),height=gender_cust_no)
plt.title('Gender Customer Distribution')
plt.xlabel('Gender Type')
plt.ylabel('Number of Gender are customers');

# %% [markdown]
# #### 3.3.1 Gender Proprtion Subscribed vs Customer

# %%
plt.figure(figsize=[12,8])

#Subscribed No for each gender
plt.subplot(1,2,1)
plt.pie(gender_sub_no,labels=gender_sub_no.index,startangle=90,autopct = '%1.2f%%',shadow = True,textprops = {"fontsize":15})
plt.title('Subscribed Gender Proption')
plt.axis('equal')

plt.subplot(1,2,2)
plt.pie(gender_cust_no,labels=gender_cust_no.index,startangle=90,autopct = '%1.2f%%',shadow = True,textprops = {"fontsize":15})
plt.title('Customer Gender Proption')
plt.axis('equal');

# %% [markdown]
# ### 3.4 Top Ten Start States vs Top Ten End States distribution

# %%
top_ten_start_states = df.start_station_name.value_counts()[:10]
top_ten_end_states = df.end_station_name.value_counts()[:10]
base_color = sb.color_palette()[0]

# %%
top_ten_start_states_df = top_ten_start_states.to_frame()
top_ten_end_states_df = top_ten_end_states.to_frame()
top_ten_start_states_df = top_ten_start_states_df.reset_index()
top_ten_end_states_df = top_ten_end_states_df.reset_index()

top_ten_start_states_df.rename(columns={'index':'start_station_name','start_station_name':'count'},inplace=True)
top_ten_end_states_df.rename(columns={'index':'end_station_name','end_station_name':'count'},inplace=True)

# %%
top_ten_end_states_df
# Out:
#                                     end_station_name  count
# 0  San Francisco Caltrain Station 2  (Townsend St...   4584
# 1                               Market St at 10th St   3636
# 2   Montgomery St BART Station (Market St at 2nd St)   3375
# 3  San Francisco Ferry Building (Harry Bridges Pl...   3084
# 4     San Francisco Caltrain (Townsend St at 4th St)   2833
# 5       Powell St BART Station (Market St at 4th St)   2811
# 6                                 Berry St at 4th St   2737
# 7                      The Embarcadero at Sansome St   2309
# 8                            Steuart St at Market St   2230
# 9       Powell St BART Station (Market St at 5th St)   2111

# %%
top_ten_start_states_df
# Out:
#                                   start_station_name  count
# 0                               Market St at 10th St   3576
# 1  San Francisco Caltrain Station 2  (Townsend St...   3370
# 2                                 Berry St at 4th St   2910
# 3   Montgomery St BART Station (Market St at 2nd St)   2643
# 4       Powell St BART Station (Market St at 4th St)   2576
# 5     San Francisco Caltrain (Townsend St at 4th St)   2551
# 6  San Francisco Ferry Building (Harry Bridges Pl...   2495
# 7                              Howard St at Beale St   2188
# 8                            Steuart St at Market St   2170
# 9       Powell St BART Station (Market St at 5th St)   2081

# %%
ax=top_ten_start_states_df.plot.barh(y='count',x='start_station_name',color=base_color,title='Top 10 Start Stations',figsize=(12,6))
ax.invert_yaxis()


ax1=top_ten_end_states_df.plot.barh(y='count',x='end_station_name',color=base_color,title='Top 10 End Stations',figsize=(12,6))
ax1.invert_yaxis()

# %% [markdown]
# ### 3.5 Day Start & Hour start count

# %%
#Plotting count of bike rides in both Day Starts & Time Start

day_start_avg_dur = (df.groupby('day_start').size()).to_frame().reset_index()
day_start_avg_dur.rename(columns = {0:'count'},inplace=True)
day_start_avg_dur
hour_start_avg_dur = (df.groupby('hour_start').size()).to_frame().reset_index()
hour_start_avg_dur.rename(columns = {0:'count'},inplace=True)
hour_start_avg_dur

ax=day_start_avg_dur.plot.barh(y='count',x='day_start',color=base_color,title='Day Start',figsize=(12,6))
ax.invert_yaxis()


ax1=hour_start_avg_dur.plot.barh(y='count',x='hour_start',color=base_color,title='Hour Start',figsize=(12,6))
ax1.invert_yaxis()

# %% [markdown]
# #### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# Plotting the trip duration distribution without transformation was misleading at which the whole graph was compressed in a narrow region. So a **log** transformation was made to expand graph for better visualization. An oulier is detected with a value about 1000 min duration which happened for about 25 trips.
#
# #### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# When investigating the user age, gender, user type, start stations, end stations most of the results were logic except for age distribution (years) there was an outlier found with value about 118 years.<br> For better intuation we made two new columns to work on "member_age" rather than "birth_date"  &  "duration" in min  rather than  "duration" in sec
#
# ## 4. Bivariate Exploration

# %% [markdown]
# ### 4.1 Age & Duration correlation

# %%
df[['member_age','duration_min']].describe()
# Out:
#           member_age   duration_min
# count  171305.000000  171305.000000
# mean       34.160649      11.629300
# std        10.116083      26.287562
# min        18.000000       1.016667
# 25%        27.000000       5.366667
# 50%        32.000000       8.483333
# 75%        39.000000      13.116667
# max       141.000000    1409.133333

# %%
plt.figure(figsize=[22,10])

plt.subplot(1,2,1)
sb.regplot(data=df,x='member_age',y='duration_min',fit_reg=False,scatter_kws={'alpha': 1/15})
plt.xticks([20,30,40,50,60,70,80,90,100,110,120,130,140])
plt.title('Correlation between Age & Duaration')
plt.xlabel('Member age(years)')
plt.ylabel('Trip Duration(min)')

plt.subplot(1,2,2)
bins_x = np.arange(18,141+5,5)
bins_y = np.arange(1,1409+70,70)

plt.hist2d(data=df,x='member_age',y='duration_min',cmin=0.5,cmap='cool',bins=[bins_x,bins_y])
plt.xticks([20,30,40,50,60,70,80,90,100,110,120,130,140])
plt.colorbar()
plt.xlabel('Member age(years)')
plt.ylabel('Trip Duration(min)');

# %% [markdown]
# ##### It is obvious from both graphs that most frequent users age between 25 & 40 years, at which higher durations occurred with younger members

# %% [markdown]
# ### 4.2 Gender & Duaration

# %%
plt.figure(figsize=[20,12]) 


plt.subplot(1,2,1)
plt.title('Male vs Female duration (Logarithmic transformation)')
sb.boxplot(data=df,x='member_gender',y='duration_min',color=base_color)
plt.yscale('log')
plt.xlabel('Gender')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15)

plt.subplot(1,2,2)
plt.title('Male vs Female duration (Y-axis limits)')
sb.boxplot(data=df,x='member_gender',y='duration_min',color=base_color)
plt.ylim([-2, 30])
plt.xlabel('Gender')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
plt.figure(figsize=[20,14]) 
plt.title('Male vs Female duration')

plt.subplot(2,1,1)
plt.title('Male vs Female duaration (BoxPlot)')
sb.boxplot(data=df,x='member_gender',y='duration_min',color=base_color)
plt.ylim([-2, 30])
plt.xlabel('Gender')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15)

plt.subplot(2,1,2)
plt.title('Male vs Female duaration (VilonPlot)')
sb.violinplot(data=df,x='member_gender',y='duration_min',color=base_color)
plt.ylim([-20, 100])
plt.xlabel('Gender')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15);

# %%
df.groupby('member_gender').mean()
# Out:
#                duration_sec  start_station_id  start_station_latitude  \
# member_gender
# Female           778.872761        138.107046               37.780751
# Male             672.394851        138.894529               37.767464
#
#                start_station_longitude  end_station_id  end_station_latitude  \
# member_gender
# Female                     -122.357255      136.301630             37.780915
# Male                       -122.349906      136.305908             37.767677
#
#                end_station_longitude      bike_id  member_birth_year  \
# member_gender
# Female                   -122.356612  4397.113565        1985.776302
# Male                     -122.349541  4507.615885        1984.546383
#
#                duration_min  member_age  hour_start
# member_gender
# Female            12.981213   33.223698   13.216076
# Male              11.206581   34.453617   13.525172

# %% [markdown]
# ##### - From Box Plot although total bumber of males > total number of females  in Univariant exoplration ,  Female avg duration > Male avg duration  in Multivariamt exoplration<br> <br> - Logarthmic transformation was used on y-axis as whole box was concentrated in a very narrow region , Other method can be used by limiting y-axis<br> <br> -  From Vilon Plot, both Males & Females most "duaration" distribution from 0 up to abot 20 min. If we look closer the region from 20 to 40 min in Female is higher.

# %% [markdown]
# ### 4.3 User type & duration

# %%
plt.figure(figsize=[20,12]) 

plt.subplot(1,2,1)
plt.title('Customer vs Subcriber duration (log transformation)')

sb.boxplot(data=df,x='user_type',y='duration_min',color=base_color)
plt.yscale('log')
plt.xlabel('User Type')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15)

plt.subplot(1,2,2)
plt.title('Customer vs Subcriber duration (y-axis scale)')

sb.boxplot(data=df,x='user_type',y='duration_min',color=base_color)
plt.ylim([-2, 60])
plt.xlabel('User Type')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15);

# %%
plt.figure(figsize=[20,15])

plt.subplot(2,1,1)
plt.title('Customer vs Subcriber duration (BoxPlot)')

sb.boxplot(data=df,x='user_type',y='duration_min',color=base_color)
plt.ylim([-2, 60])
plt.xlabel('User Type')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15)

plt.subplot(2,1,2)
plt.title('Customer vs Subcriber duration (VilonPlot)')
sb.violinplot(data=df,x='user_type',y='duration_min',color=base_color)
plt.ylim([-50, 150])
plt.xlabel('User Type')
plt.ylabel('Duaration(min)')
plt.xticks(rotation=15);

# %% [markdown]
# ##### -  From Boxplots, It is obvious that "Customer" user mean duration > “Subscriber" user mean duration  <br> <br> - From Villon plots, it is obvious in range 0 to 20 min "Subscriber" user distribution is much more than "Customer" user.<br><br> - On the other hand, in range 25 - 40 min "Customer" user distribution is much more than "Subscriber" user. <br> <br> - Logarithmic transformation was used on y-axis as whole box was concentrated in a very narrow region, other method can be used by limiting y-axis.

# %% [markdown]
# ### 4.4 Day Start & Hour Start

# %%
hour_counts = df.groupby(['day_start','hour_start']).size()
hour_counts = hour_counts.reset_index(name = 'count')
hour_counts = hour_counts.pivot(index = 'hour_start', columns = 'day_start', values = 'count')
col_names = ['Monday','Sunday','Tuesday','Wednesday','Thursday','Friday','Saturday']
hour_counts = hour_counts.reindex(columns=col_names)
hour_counts.head()
# Out:
# day_start   Monday  Sunday  Tuesday  Wednesday  Thursday  Friday  Saturday
# hour_start
# 0               96     148       78         82       118     139       208
# 1               43      96       53         44        41      78       154
# 2               37      87       32         28        24      59        73
# 3               18      33       17         13        20      28        23
# 4               35      20       30         26        40      42        22

# %%
plt.figure(figsize=(18, 6))
sb.heatmap(hour_counts)
plt.title('Bike usage per hour')
plt.ylabel('Hour')
plt.xlabel('Day');

# %% [markdown]
# ##### It is obvious here that most users take bikes early in the morning & at evening after work

# %% [markdown]
# ### 4.5 Start Day & Duration

# %%
plt.figure(figsize=[18,10])

sb.violinplot(data=df,x='day_start',y='duration_min',color=base_color,order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.ylim(-20,90)
plt.title('Duration per day')
plt.ylabel('Duration (min)')
plt.xlabel('Day')
plt.xticks(rotation=15);

# %% [markdown]
# ##### - It seems that on weekends "Saturday" & "Sunday" more rides are taken which logic. <br> <br> - What is strange that in same duration range 0 to 20 min work days have much larger distribution in duration.

# %% [markdown]
# ## 5. Multivariate Exploration

# %% [markdown]
# ### 5.1 Age & Gender with Duration distribution

# %%
g = sb.FacetGrid(data=df,hue='member_gender',palette='Set1',hue_order=['Male','Female'],height=5,aspect=3)
g = g.map(plt.scatter,'member_age','duration_min',alpha=1/15)
g.add_legend()
plt.title('Duration per age seperated by gender')
plt.xlabel("Member Age (years)")
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - It seems that males are most dominant in duration up to abot 100 min with age range 20-60 years.<br> <br> - With age range 20-60 years, females appeares more in higher duration which explains from Mulivariate Expolration why females have higher avg duration.

# %% [markdown]
# ### 5.2 Age & User Type with Duration distribution

# %%
g = sb.FacetGrid(data=df,hue='user_type',palette='Set1',hue_order=['Customer','Subscriber'],height=5,aspect=3)
g = g.map(plt.scatter,'member_age','duration_min',alpha=1/15)
g.add_legend()
plt.title('Duration per age seperated by customer type')
plt.xlabel("Member Age (years)")
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - It seems that subscriber members are much more than Customers with age range 20-70 years.<br><br> - At about 18 years old. it seems that there almost no Subscribers which is somehow logic for teenagers to just rent the bikes.

# %% [markdown]
# ### 5.3 Age & Day Start with Duration distribution

# %%
g = sb.FacetGrid(data=df,hue='day_start',palette='inferno_r',hue_order=['Saturday','Sunday','Monday','Tuesday','Wednesday','Thursday','Friday'],height=5,aspect=3)
g = g.map(sb.regplot,'member_age','duration_min',fit_reg=False)
g.add_legend()
plt.title('Duration per age seperated by day start')
plt.xlabel("Member Age (years)")
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - This explains that the most day members use bikes is Friday then comes Saturday, which is logic as they are the weekends.

# %% [markdown]
# ### 5.4 Day Start & Gender with Duration distribution

# %%
plt.figure(figsize=[12,8])
sb.boxplot(data = df, x = 'day_start', y = 'duration_min', hue = 'member_gender', order = ['Saturday','Sunday','Monday','Tuesday','Wednesday','Thursday','Friday']);

# %% [markdown]
# ##### It seems that a logarithmic transformation is needed

# %%
plt.figure(figsize=[18,10])
sb.boxplot(data = df, x = 'day_start', y = 'duration_min', hue = 'member_gender', order = ['Saturday','Sunday','Monday','Tuesday','Wednesday','Thursday','Friday'])
plt.yscale('log')
plt.xticks(rotation=15)
plt.title('Duration per day start seperated by gender')
plt.xlabel('Start Day')
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - In all days, females have high avg duration than males.

# %%
plt.figure(figsize=[18,10])
sb.boxplot(data = df, x = 'day_start', y = 'duration_min', hue = 'user_type')
plt.yscale('log')
plt.xticks(rotation=15)
plt.title('Duration per day start seperated by user type')
plt.xlabel('Start Day')
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - Customer users make more duration than Subscriber users in all days.<br><br> - Max duration day is Sunday for Customers

# %%
plt.figure(figsize=[18,10])
sb.barplot(data = df, x = 'hour_start', y = 'duration_min', hue = 'user_type')
plt.xticks(rotation=15)
plt.title('Duration per start time seperated by user type')
plt.xlabel('Start Time')
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - Customers make more duration in all starting times than Subscribers.<br><br> - For Customers, most dominant starting times are 2 & 3 pm with greatest probability of outliers can occuer reaching at 3 pm an outlier with value 120 min.<br><br> - For Customers, least dominant starting times are 5 & 6 pm.<br><br> - For Subscribers, most dominant starting times is 3 pm.<br><br> - For Subscribers, least dominant starting times are 5 & 6 pm.

# %%
plt.figure(figsize=[18,10])
sb.barplot(data = df, x = 'hour_start', y = 'duration_min', hue = 'member_gender')
plt.xticks(rotation=15)
plt.title('Duration per start time seperated by gender')
plt.xlabel('Start Time')
plt.ylabel('Duration (min)');

# %% [markdown]
# ##### - Females make more duration in all starting times than Males except at 5 & 23.<br><br> - For Females most dominant starting times are 2 & 3 pm with greatest probability of outliers can occuer reaching at 3 pm an outlier with value  about 110 min..<br><br> - For Females, least dominant starting times are 5 & 6 pm.<br><br> - For Males, most dominant starting times is 3 pm.<br><br> - For Males, least dominant starting times are 6 & 7 pm.
